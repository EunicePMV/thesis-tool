# %%
import json

# Assuming you have a JSON file named 'data.json'
file_path = 'PSOreports.json'

# Load JSON data from the file
with open(file_path, 'r') as file:
    data = json.load(file)

# Now 'data' contains the contents of the JSON file
print(json.dumps(data, indent=2))
# Out:
# {
#   "fold-1": {
#     "blb": {
#       "precision": 0.987012987012987,
#       "recall": 0.95,
#       "f1-score": 0.9681528662420381,
#       "support": 80.0
#     },
#     "hlt": {
#       "precision": 0.8356164383561644,
#       "recall": 0.9384615384615385,
#       "f1-score": 0.8840579710144928,
#       "support": 65.0
#     },
#     "rb": {
#       "precision": 0.9384615384615385,
#       "recall": 0.9242424242424242,
#       "f1-score": 0.9312977099236641,
#       "support": 66.0
#     },
#     "sb": {
#       "precision": 1.0,
#       "recall": 0.948051948051948,
#       "f1-score": 0.9733333333333333,
#       "support": 77.0
#     },
#     "accuracy": 0.9409722222222222,
#     "macro avg": {
#       "precision": 0.9402727409576725,
#       "recall": 0.9401889776889777,
#       "f1-score": 0.939210470128382,
#       "support": 288.0
#     },
#     "weighted avg": {
#       "precision": 0.9451894756689279,
#       "recall": 0.9409722222222222,
#       "f1-score": 0.9421121976976861,
#       "support": 288.0
#     }
#   },
#   "fold-2": {
#     "blb": {
#       "precision": 0.9682539682539683,
#       "recall": 0.9682539682539683,
#       "f1-score": 0.9682539682539683,
#       "support": 63.0
#     },
#     "hlt": {
#       "precision": 0.918918918918919,
#       "recall": 0.9315068493150684,
#       "f1-score": 0.9251700680272108,
#       "support": 73.0
#     },
#     "rb": {
#       "precision": 0.9367088607594937,
#       "recall": 0.9736842105263158,
#       "f1-score": 0.9548387096774194,
#       "support": 76.0
#     },
#     "sb": {
#       "precision": 1.0,
#       "recall": 0.9473684210526315,
#       "f1-score": 0.972972972972973,
#       "support": 76.0
#     },
#     "accuracy": 0.9548611111111112,
#     "macro avg": {
#       "precision": 0.9559704369830953,
#       "recall": 0.955203362286996,
#       "f1-score": 0.9553089297328927,
#       "support": 288.0
#     },
#     "weighted avg": {
#       "precision": 0.9558019253430646,
#       "recall": 0.9548611111111112,
#       "f1-score": 0.9550385515535285,
#       "support": 288.0
#     }
#   },
#   "fold-3": {
#     "blb": {
#       "precision": 0.958904109589041,
#       "recall": 0.9722222222222222,
#       "f1-score": 0.9655172413793104,
#       "support": 72.0
#     },
#     "hlt": {
#       "precision": 0.9425287356321839,
#       "recall": 0.9879518072289156,
#       "f1-score": 0.9647058823529412,
#       "support": 83.0
#     },
#     "rb": {
#       "precision": 0.9682539682539683,
#       "recall": 0.9104477611940298,
#       "f1-score": 0.9384615384615386,
#       "support": 67.0
#     },
#     "sb": {
#       "precision": 0.9846153846153847,
#       "recall": 0.9696969696969697,
#       "f1-score": 0.9770992366412214,
#       "support": 66.0
#     },
#     "accuracy": 0.9618055555555556,
#     "macro avg": {
#       "precision": 0.9635755495226445,
#       "recall": 0.9600796900855344,
#       "f1-score": 0.9614459747087529,
#       "support": 288.0
#     },
#     "weighted avg": {
#       "precision": 0.9622521257135885,
#       "recall": 0.9618055555555556,
#       "f1-score": 0.9616434107980838,
#       "support": 288.0
#     }
#   },
#   "fold-4": {
#     "blb": {
#       "precision": 0.9516129032258065,
#       "recall": 0.8939393939393939,
#       "f1-score": 0.921875,
#       "support": 66.0
#     },
#     "hlt": {
#       "precision": 0.918918918918919,
#       "recall": 0.9714285714285714,
#       "f1-score": 0.9444444444444445,
#       "support": 70.0
#     },
#     "rb": {
#       "precision": 0.9615384615384616,
#       "recall": 0.9615384615384616,
#       "f1-score": 0.9615384615384616,
#       "support": 78.0
#     },
#     "sb": {
#       "precision": 0.972972972972973,
#       "recall": 0.972972972972973,
#       "f1-score": 0.972972972972973,
#       "support": 74.0
#     },
#     "accuracy": 0.9513888888888888,
#     "macro avg": {
#       "precision": 0.95126081416404,
#       "recall": 0.9499698499698499,
#       "f1-score": 0.9502077197389698,
#       "support": 288.0
#     },
#     "weighted avg": {
#       "precision": 0.9518429720042624,
#       "recall": 0.9513888888888888,
#       "f1-score": 0.9512321566358024,
#       "support": 288.0
#     }
#   }
# }

# %%
from IPython.display import JSON

# Display the prettified JSON data
JSON(data)

# %%
import numpy as np
import matplotlib.pyplot as plt

json_data = data

# Extracting data from the JSON
folds = ["fold-1", "fold-2", "fold-3", "fold-4"]
classes = ["blb", "hlt", "rb", "sb"]

precision_data = {fold: {cls: data[cls]["precision"] for cls in classes} for fold, data in json_data.items()}
recall_data = {fold: {cls: data[cls]["recall"] for cls in classes} for fold, data in json_data.items()}
f1_data = {fold: {cls: data[cls]["f1-score"] for cls in classes} for fold, data in json_data.items()}

# Create a grouped bar plot for each metric
for cls in classes:
    precision_values = [precision_data[fold][cls] for fold in folds]
    recall_values = [recall_data[fold][cls] for fold in folds]
    f1_values = [f1_data[fold][cls] for fold in folds]

    bar_width = 0.25
    index = np.arange(len(folds))

    plt.bar(index, precision_values, width=bar_width, label='Precision')
    plt.bar(index + bar_width, recall_values, width=bar_width, label='Recall')
    plt.bar(index + 2 * bar_width, f1_values, width=bar_width, label='F1-score')

    plt.xlabel('Folds')
    plt.ylabel('Metrics')
    plt.title(f'{cls} Metrics Across Folds')
    plt.xticks(index + bar_width, [f'{fold}\nPrecision' for fold in folds])
    plt.legend()
    plt.show()

# %%
pso_metrics = data

accuracy_data = {fold: pso_metrics[fold]["accuracy"] for fold in folds}

# Plotting accuracy across folds
plt.figure(figsize=(10, 6))
plt.plot(folds, [accuracy_data[fold] for fold in folds], marker='o')
plt.title("Accuracy Across Folds")
plt.xlabel("Folds")
plt.ylabel("Accuracy")
plt.show()
plt.show()
